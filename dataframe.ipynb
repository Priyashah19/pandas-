# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/exam/Desktop/uber.csv')

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
df.describe()
# Out:
#              MILES*
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-72b44c061663> in <module>()
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.iloc[:,::2] #::2 will print every 2nd column
# Out:
#            START_DATE* CATEGORY*             STOP*         PURPOSE*
# 0       1/1/2016 21:11  Business       Fort Pierce   Meal/Entertain
# 1        1/2/2016 1:25  Business       Fort Pierce              NaN
# 2       1/2/2016 20:25  Business       Fort Pierce  Errand/Supplies
# 3       1/5/2016 17:31  Business       Fort Pierce          Meeting
# 4       1/6/2016 14:42  Business   West Palm Beach   Customer Visit
# 5       1/6/2016 17:15  Business   West Palm Beach   Meal/Entertain
# 6       1/6/2016 17:30  Business        Palm Beach          Meeting
# 7       1/7/2016 13:27  Business              Cary          Meeting
# 8       1/10/2016 8:05  Business       Morrisville          Meeting
# 9      1/10/2016 12:17  Business          New York   Customer Visit
# 10     1/10/2016 15:08  Business            Queens          Meeting
# 11     1/10/2016 18:18  Business          New York          Meeting
# 12     1/10/2016 19:12  Business       East Harlem          Meeting
# ...

# %%
df.isnill()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-2cc0295024ea> in <module>()
# ----> 1 df.isna()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'isna'

# %%
df.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
df.isnull()
# Out:
#       START_DATE*  END_DATE*  CATEGORY*  START*  STOP*  MILES*  PURPOSE*
# 0           False      False      False   False  False   False     False
# 1           False      False      False   False  False   False      True
# 2           False      False      False   False  False   False     False
# 3           False      False      False   False  False   False     False
# 4           False      False      False   False  False   False     False
# 5           False      False      False   False  False   False     False
# 6           False      False      False   False  False   False     False
# 7           False      False      False   False  False   False     False
# 8           False      False      False   False  False   False     False
# 9           False      False      False   False  False   False     False
# 10          False      False      False   False  False   False     False
# 11          False      False      False   False  False   False     False
# ...

# %%
dt=df.dropna(inplace=False)#it will delete every row with value false
#dt=df.dropna(inplace=True)--True will delete original

# %%
dt
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# 12     1/10/2016 19:12   1/10/2016 19:32  Business            Midtown
# ...

# %%
df['PURPOSE*'].dtype
# Out:
# dtype('O')

# %%
df['PURPOSE*'].values
# Out:
# array(['Meal/Entertain', nan, 'Errand/Supplies', ..., 'Temporary Site',
#        'Temporary Site', nan], dtype=object)

# %%
#overwrited to meeting in purpose column
df['PURPOSE*']='Meeting'

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
#to find diff between start date and end date and their duration should be saved in new column called diff
#method-1
df[['START_DATE*','END_DATE*']] = df[['START_DATE*','END_DATE*']].apply(pd.to_datetime)
df['Difference'] = df['END_DATE*'] - df['START_DATE*']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     443             try:
# --> 444                 values, tz = tslib.datetime_to_datetime64(arg)
#     445                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.datetime_to_datetime64 (pandas/_libs/tslib.c:33275)()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-eeb5f6f05536> in <module>()
#       1 from pandas import datetime
# ----> 2 df[['START_DATE*','END_DATE*']] = df[['START_DATE*','END_DATE*']].apply(pd.to_datetime)
# ...

# %%
#to find diff between start date and end date and their duration should be saved in new column called diff
#method-2
from pandas import datetime
sdt = pd.to_datetime(df['START_DATE*'],errors='coerce')

# %%
sdt
# Out:
# 0      2016-01-01 21:11:00
# 1      2016-01-02 01:25:00
# 2      2016-01-02 20:25:00
# 3      2016-01-05 17:31:00
# 4      2016-01-06 14:42:00
# 5      2016-01-06 17:15:00
# 6      2016-01-06 17:30:00
# 7      2016-01-07 13:27:00
# 8      2016-01-10 08:05:00
# 9      2016-01-10 12:17:00
# 10     2016-01-10 15:08:00
# 11     2016-01-10 18:18:00
# 12     2016-01-10 19:12:00
# 13     2016-01-11 08:55:00
# 14     2016-01-11 11:56:00
# 15     2016-01-11 13:32:00
# 16     2016-01-11 14:30:00
# 17     2016-01-12 12:33:00
# 18     2016-01-12 12:53:00
# 19     2016-01-12 14:42:00
# 20     2016-01-12 15:13:00
# 21     2016-01-12 15:42:00
# 22     2016-01-12 16:02:00
# 23     2016-01-13 13:54:00
# 24     2016-01-13 15:00:00
# 25     2016-01-14 16:29:00
# 26     2016-01-14 21:39:00
# 27     2016-01-15 00:41:00
# 28     2016-01-15 11:43:00
# 29     2016-01-15 13:26:00
#                ...
# 1126   2016-12-28 11:42:00
# 1127   2016-12-28 13:53:00
# 1128   2016-12-28 15:04:00
# ...

# %%
edt = pd.to_datetime(df['END_DATE*'],errors='coerce')#coerce is used to ignore string errors in to_datetime

# %%
edt
# Out:
# 0      2016-01-01 21:17:00
# 1      2016-01-02 01:37:00
# 2      2016-01-02 20:38:00
# 3      2016-01-05 17:45:00
# 4      2016-01-06 15:49:00
# 5      2016-01-06 17:19:00
# 6      2016-01-06 17:35:00
# 7      2016-01-07 13:33:00
# 8      2016-01-10 08:25:00
# 9      2016-01-10 12:44:00
# 10     2016-01-10 15:51:00
# 11     2016-01-10 18:53:00
# 12     2016-01-10 19:32:00
# 13     2016-01-11 09:21:00
# 14     2016-01-11 12:03:00
# 15     2016-01-11 13:46:00
# 16     2016-01-11 14:43:00
# 17     2016-01-12 12:49:00
# 18     2016-01-12 13:09:00
# 19     2016-01-12 14:56:00
# 20     2016-01-12 15:28:00
# 21     2016-01-12 15:54:00
# 22     2016-01-12 17:00:00
# 23     2016-01-13 14:07:00
# 24     2016-01-13 15:28:00
# 25     2016-01-14 17:05:00
# 26     2016-01-14 21:45:00
# 27     2016-01-15 01:01:00
# 28     2016-01-15 12:03:00
# 29     2016-01-15 13:44:00
#                ...
# 1126   2016-12-28 12:12:00
# 1127   2016-12-28 14:01:00
# 1128   2016-12-28 15:39:00
# ...

# %%
df['diff']=edt-sdt

# %%
df['diff']
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
#new column added named status with values completed
df['Status']='Completed'

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
del df['diff']#deletes the column

# %%
#will return the name of the columns present in given csv file
df.columns
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*', 'Status'],
#       dtype='object')

# %%
#will print miles greater than 5
dm = df[df['MILES*'] > 5]
print('Resulted Miles :', dm)
# Out:
# Resulted Miles :            START_DATE*         END_DATE* CATEGORY*               START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business          Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business          Fort Pierce
# 6       1/6/2016 17:30    1/6/2016 17:35  Business      West Palm Beach
# 8       1/10/2016 8:05    1/10/2016 8:25  Business                 Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business              Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business             New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business             Elmhurst
# 12     1/10/2016 19:12   1/10/2016 19:32  Business              Midtown
# 13      1/11/2016 8:55    1/11/2016 9:21  Business          East Harlem
# 22     1/12/2016 16:02   1/12/2016 17:00  Business             New York
# 23     1/13/2016 13:54   1/13/2016 14:07  Business             Downtown
# 24     1/13/2016 15:00   1/13/2016 15:28  Business              Gulfton
# ...
