# %%
import pandas as pd

# %%
df=pd.read_csv("/Users/exam/Desktop/uber.csv")

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
df.count
# Out:
# <bound method DataFrame.count of            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1156, step=1)

# %%
df.columns
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')

# %%
df.count
# Out:
# <bound method DataFrame.count of            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
df.head(10)
# Out:
#        START_DATE*        END_DATE* CATEGORY*           START*  \
# 0   1/1/2016 21:11   1/1/2016 21:17  Business      Fort Pierce
# 1    1/2/2016 1:25    1/2/2016 1:37  Business      Fort Pierce
# 2   1/2/2016 20:25   1/2/2016 20:38  Business      Fort Pierce
# 3   1/5/2016 17:31   1/5/2016 17:45  Business      Fort Pierce
# 4   1/6/2016 14:42   1/6/2016 15:49  Business      Fort Pierce
# 5   1/6/2016 17:15   1/6/2016 17:19  Business  West Palm Beach
# 6   1/6/2016 17:30   1/6/2016 17:35  Business  West Palm Beach
# 7   1/7/2016 13:27   1/7/2016 13:33  Business             Cary
# 8   1/10/2016 8:05   1/10/2016 8:25  Business             Cary
# 9  1/10/2016 12:17  1/10/2016 12:44  Business          Jamaica
#
#              STOP*  MILES*         PURPOSE*
# 0      Fort Pierce     5.1   Meal/Entertain
# 1      Fort Pierce     5.0              NaN
# 2      Fort Pierce     4.8  Errand/Supplies
# 3      Fort Pierce     4.7          Meeting
# 4  West Palm Beach    63.7   Customer Visit
# ...

# %%
df[3:]
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*  \
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# 12     1/10/2016 19:12   1/10/2016 19:32  Business            Midtown
# 13      1/11/2016 8:55    1/11/2016 9:21  Business        East Harlem
# 14     1/11/2016 11:56   1/11/2016 12:03  Business  Flatiron District
# ...

# %%
import pandas as pd

# %%
db=pd.read_csv("/Users/exam/Desktop/netflix_titles.csv")

# %%
db
# Out:
#          s1  TV Show                                                 3%  \
# 0        s2    Movie                                               7:19
# 1        s3    Movie                                              23:59
# 2        s4    Movie                                                  9
# 3        s5    Movie                                                 21
# 4        s6  TV Show                                                 46
# 5        s7    Movie                                                122
# 6        s8    Movie                                                187
# 7        s9    Movie                                                706
# 8       s10    Movie                                               1920
# 9       s11    Movie                                               1922
# 10      s12  TV Show                                               1983
# 11      s13  TV Show                                               1994
# ...

# %%
db.info
# Out:
# <bound method DataFrame.info of          s1  TV Show                                                 3%  \
# 0        s2    Movie                                               7:19
# 1        s3    Movie                                              23:59
# 2        s4    Movie                                                  9
# 3        s5    Movie                                                 21
# 4        s6  TV Show                                                 46
# 5        s7    Movie                                                122
# 6        s8    Movie                                                187
# 7        s9    Movie                                                706
# 8       s10    Movie                                               1920
# 9       s11    Movie                                               1922
# 10      s12  TV Show                                               1983
# 11      s13  TV Show                                               1994
# ...

# %%
db.count
# Out:
# <bound method DataFrame.count of          s1  TV Show                                                 3%  \
# 0        s2    Movie                                               7:19
# 1        s3    Movie                                              23:59
# 2        s4    Movie                                                  9
# 3        s5    Movie                                                 21
# 4        s6  TV Show                                                 46
# 5        s7    Movie                                                122
# 6        s8    Movie                                                187
# 7        s9    Movie                                                706
# 8       s10    Movie                                               1920
# 9       s11    Movie                                               1922
# 10      s12  TV Show                                               1983
# 11      s13  TV Show                                               1994
# ...

# %%
db.head()
# Out:
#    s1  TV Show     3%         Unnamed: 3  \
# 0  s2    Movie   7:19  Jorge Michel Grau
# 1  s3    Movie  23:59       Gilbert Chan
# 2  s4    Movie      9        Shane Acker
# 3  s5    Movie     21     Robert Luketic
# 4  s6  TV Show     46        Serdar Akar
#
#   João Miguel, Bianca Comparato, Michel Gomes, Rodolfo Valente, Vaneza Oliveira, Rafael Lozano, Viviane Porto, Mel Fronckowiak, Sergio Mamberti, Zezé Motta, Celso Frateschi  \
# 0  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 1  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 2  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 3  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 4  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
#
#           Brazil    August 14, 2020  2020  TV-MA 4 Seasons  \
# 0         Mexico  December 23, 2016  2016  TV-MA    93 min
# 1      Singapore  December 20, 2018  2011      R    78 min
# 2  United States  November 16, 2017  2009  PG-13    80 min
# ...

# %%
db.tail()
# Out:
#          s1  TV Show              3%     Unnamed: 3  \
# 1048  s1050  TV Show     Borderliner            NaN
# 1049  s1051  TV Show      Bordertown            NaN
# 1050  s1052  TV Show          Borgen            NaN
# 1051  s1053  TV Show          Borges            NaN
# 1052  s1054    Movie  Born Beautiful  Perci Intalan
#
#      João Miguel, Bianca Comparato, Michel Gomes, Rodolfo Valente, Vaneza Oliveira, Rafael Lozano, Viviane Porto, Mel Fronckowiak, Sergio Mamberti, Zezé Motta, Celso Frateschi  \
# 1048  Tobias Santelmann, Ellen Dorrit Petersen, Benj...
# 1049  Ville Virtanen, Matleena Kuusniemi, Anu Sinisa...
# 1050  Sidse Babett Knudsen, Birgitte Hjort Sørensen,...
# 1051  Thati Lopes, Antonio Pedro Tabet, Karina Ramil...
# 1052  Martin del Rosario, Lou Veloso, Chai Fonacier,...
#
#                        Brazil    August 14, 2020  2020  TV-MA  4 Seasons  \
# 1048  Norway, Germany, Sweden      March 6, 2018  2017  TV-MA   1 Season
# ...

# %%
db.head(6)
# Out:
#    s1  TV Show     3%         Unnamed: 3  \
# 0  s2    Movie   7:19  Jorge Michel Grau
# 1  s3    Movie  23:59       Gilbert Chan
# 2  s4    Movie      9        Shane Acker
# 3  s5    Movie     21     Robert Luketic
# 4  s6  TV Show     46        Serdar Akar
# 5  s7    Movie    122    Yasir Al Yasiri
#
#   João Miguel, Bianca Comparato, Michel Gomes, Rodolfo Valente, Vaneza Oliveira, Rafael Lozano, Viviane Porto, Mel Fronckowiak, Sergio Mamberti, Zezé Motta, Celso Frateschi  \
# 0  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 1  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 2  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 3  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 4  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
# 5  Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...
#
#           Brazil    August 14, 2020  2020  TV-MA 4 Seasons  \
# 0         Mexico  December 23, 2016  2016  TV-MA    93 min
# ...

# %%
db.tail(6)
# Out:
#          s1  TV Show              3%     Unnamed: 3  \
# 1047  s1049  TV Show      Borderline            NaN
# 1048  s1050  TV Show     Borderliner            NaN
# 1049  s1051  TV Show      Bordertown            NaN
# 1050  s1052  TV Show          Borgen            NaN
# 1051  s1053  TV Show          Borges            NaN
# 1052  s1054    Movie  Born Beautiful  Perci Intalan
#
#      João Miguel, Bianca Comparato, Michel Gomes, Rodolfo Valente, Vaneza Oliveira, Rafael Lozano, Viviane Porto, Mel Fronckowiak, Sergio Mamberti, Zezé Motta, Celso Frateschi  \
# 1047  David Avery, Jackie Clune, David Elms, Liz Kin...
# 1048  Tobias Santelmann, Ellen Dorrit Petersen, Benj...
# 1049  Ville Virtanen, Matleena Kuusniemi, Anu Sinisa...
# 1050  Sidse Babett Knudsen, Birgitte Hjort Sørensen,...
# 1051  Thati Lopes, Antonio Pedro Tabet, Karina Ramil...
# 1052  Martin del Rosario, Lou Veloso, Chai Fonacier,...
#
#                        Brazil    August 14, 2020  2020  TV-MA  4 Seasons  \
# ...

# %%
db[6:]
# Out:
#          s1  TV Show                                                 3%  \
# 6        s8    Movie                                                187
# 7        s9    Movie                                                706
# 8       s10    Movie                                               1920
# 9       s11    Movie                                               1922
# 10      s12  TV Show                                               1983
# 11      s13  TV Show                                               1994
# 12      s14    Movie                                               2215
# 13      s15    Movie                                               3022
# 14      s16    Movie                                             Oct-01
# 15      s17  TV Show                                             Feb-09
# 16      s18    Movie                                             22-Jul
# 17      s19    Movie                                             15-Aug
# ...

# %%
db[:5]
# Out:
#    s1  TV Show     3%         Unnamed: 3  \
# 0  s2    Movie   7:19  Jorge Michel Grau
# 1  s3    Movie  23:59       Gilbert Chan
# 2  s4    Movie      9        Shane Acker
# 3  s5    Movie     21     Robert Luketic
# 4  s6  TV Show     46        Serdar Akar
#
#   João Miguel, Bianca Comparato, Michel Gomes, Rodolfo Valente, Vaneza Oliveira, Rafael Lozano, Viviane Porto, Mel Fronckowiak, Sergio Mamberti, Zezé Motta, Celso Frateschi  \
# 0  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 1  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 2  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 3  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 4  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
#
#           Brazil    August 14, 2020  2020  TV-MA 4 Seasons  \
# 0         Mexico  December 23, 2016  2016  TV-MA    93 min
# 1      Singapore  December 20, 2018  2011      R    78 min
# 2  United States  November 16, 2017  2009  PG-13    80 min
# ...

# %%
db[::4]
# Out:
#          s1  TV Show                                   3%  \
# 0        s2    Movie                                 7:19
# 4        s6  TV Show                                   46
# 8       s10    Movie                                 1920
# 12      s14    Movie                                 2215
# 16      s18    Movie                               22-Jul
# 20      s22    Movie                         ​Goli Soda 2
# 24      s26    Movie                             (T)ERROR
# 28      s30  TV Show                             #blackAF
# 32      s34    Movie                         #realityhigh
# 36      s38    Movie                           #Selfie 69
# 40      s42    Movie                           Ég man þig
# 44      s46  TV Show                                Şubat
# 48      s50    Movie                       10 jours en or
# 52      s54  TV Show                           100 Humans
# 56      s58    Movie                           100% Halal
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1156, step=1)

# %%
df.columns
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')

# %%
df['CATEGORY*']
# Out:
# 0       Business
# 1       Business
# 2       Business
# 3       Business
# 4       Business
# 5       Business
# 6       Business
# 7       Business
# 8       Business
# 9       Business
# 10      Business
# 11      Business
# 12      Business
# 13      Business
# 14      Business
# 15      Business
# 16      Business
# 17      Business
# 18      Business
# 19      Business
# 20      Business
# 21      Business
# 22      Business
# 23      Business
# 24      Business
# 25      Business
# 26      Business
# 27      Business
# 28      Business
# 29      Business
#           ...
# 1126    Business
# 1127    Business
# 1128    Business
# 1129    Business
# 1130    Business
# 1131    Business
# 1132    Business
# 1133    Business
# 1134    Business
# 1135    Business
# 1136    Business
# 1137    Business
# 1138    Business
# 1139    Business
# 1140    Business
# 1141    Business
# 1142    Business
# 1143    Business
# 1144    Business
# 1145    Business
# 1146    Business
# ...

# %%
df['CATEGORY*'].value_counts()
# Out:
# Business    1078
# Personal      77
# Name: CATEGORY*, dtype: int64

# %%
df['CATEGORY*'].count()
# Out:
# 1155

# %%
df.iloc[3]
# Out:
# START_DATE*    1/5/2016 17:31
# END_DATE*      1/5/2016 17:45
# CATEGORY*            Business
# START*            Fort Pierce
# STOP*             Fort Pierce
# MILES*                    4.7
# PURPOSE*              Meeting
# Name: 3, dtype: object

# %%
df.iloc[3,3]
# Out:
# 'Fort Pierce'

# %%
df.iloc[101,5]
# Out:
# 8.9000000000000004

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...
